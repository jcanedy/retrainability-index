# %%
import gcsfs
from google.colab import auth
import polars as pl

# %%
auth.authenticate_user()
# Out:
# ---------------------------------------------------------------------------
# AuthorizationError                        Traceback (most recent call last)
# /tmp/ipython-input-4149171672.py in <cell line: 0>()
# ----> 1 auth.authenticate_user()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     267       context_manager = _output.temporary if clear_output else _noop
#     268       with context_manager():
# --> 269         _gcloud_login()
#     270       _install_adc()
#     271   if _check_adc(_CredentialType.USER):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/auth.py in _gcloud_login()
#     173     _os.remove(name)
#     174   if gcloud_process.returncode:
# --> 175     raise _errors.AuthorizationError('Error fetching credentials')
#     176
#     177
#
# AuthorizationError: Error fetching credentials

# %%
fs = gcsfs.GCSFileSystem(project="retraining-index")

with fs.open("retrainability-index/processed/workforce_boards/workforce_boards_all_grouped.parquet", "rb") as f:
     df_workforce_boards = pl.read_parquet(f)
# Out:
# ERROR:gcsfs:_request non-retriable exception: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gcsfs/retry.py", line 135, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gcsfs/core.py", line 470, in _request
#     validate_response(status, contents, path, args)
#   File "/usr/local/lib/python3.12/dist-packages/gcsfs/retry.py", line 122, in validate_response
#     raise HttpError(error)
# gcsfs.retry.HttpError: Anonymous caller does not have storage.objects.get access to the Google Cloud Storage object. Permission 'storage.objects.get' denied on resource (or it may not exist)., 401
# ---------------------------------------------------------------------------
# ...

# %%
https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http s%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3А%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3А%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=ARD89R4ZZ31|D6kWUac3VHf5bONrkL&prompt=consent&token_usage=remote&access_type=offline&code_challenge=_252AiBTmPURLU96rRznhMWMRX6ZM2ukgvGsWykTY-k&code_challenge_method=S256
