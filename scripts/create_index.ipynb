# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from itertools import combinations
import polars as pl

# %%
DATA_FOLDER = "../data/processed"

# %%
# Remap numeric column values to interpretable values.
sex_map = {
    1: "Male",
    2: "Female",
    9: "Participant did not self-identify",
}

employment_status_map = {
    1: "Employed",
    2: "Employed, but Received Notice of \
    Termination of Employment or Military \
    Separation is pending",
    3: "Not in labor force",
    0: "Unemployed"
}

race_map = {
    1: "Hispanic",
    2: "Asian (not Hispanic)",
    3: "Black (not Hispanic)",
    4: "Native Hawaiian or Pacific Islander (not Hispanic)",
    5: "American Indian or Alaska Native (not Hispanic)",
    6: "White (not Hispanic)",
    7: "Multiple Race (not Hispanic)",
}

def age_map(age):
  if (age < 5):
    return "Under 5 years"
  elif (5 <= age < 17):
    return "5 to 17 years"
  elif (17 <= age < 25):
    return "17 to 24 years"
  elif (25 <= age < 35):
    return "25 to 34 years"
  elif (35 <= age < 45):
    return "35 to 44 years"
  elif (45 <= age < 55):
    return "45 to 54 years"
  elif (55 <= age < 65):
    return "55 to 64 years"
  elif (65 <= age < 85):
    return "65 to 84 years"
  elif (85 <= age < 100):
    return "85 to 99 years"
  elif (100 <= age):
    return "100 years and over"
  else:
    return "Unknown"

highest_educational_level_map = {
  1: "Attained secondary school diploma",
  2: "Attained a secondary school equivalency",
  3: "The participant with a disability receives \
  a certificate of attendance/completion as a \
  result of successfully completing an \
  Individualized Education Program (IEP)",
  4: "Completed one of more years of postsecondary education",
  5: "Attained a postsecondary technical or vocational certificate (non-degree)",
  6: "Attained an Associate's degree",
  7: "Attained a Bachelor's degree",
  8: "Attained a degree beyond a Bachelor's degree",
  0: "No Educational Level Completed",
}

low_income_status_map = {
    1: "Yes",
    0: "No"
}

received_training_map = {
  1: "Yes",
  0: "No"
}

# %%
occupations = pl.scan_csv(f"{DATA_FOLDER}/occupations.csv")
workforce_boards = pl.scan_csv(f"{DATA_FOLDER}/workforce_boards.csv")

# %%
rti_by_subsector = pl.scan_parquet(f"{DATA_FOLDER}/rti_by_subsector.parquet")
rti_by_industry = pl.scan_parquet(f"{DATA_FOLDER}/rti_by_industry.parquet")
rti_by_occupation = pl.scan_parquet(f"{DATA_FOLDER}/rti_by_occupation.parquet")

# %%
data_lazy = pl.scan_parquet(f"{DATA_FOLDER}/wioa_data_filtered.parquet")

# %%
data_lazy = (
    data_lazy
    .with_columns([
      pl.col("sex").replace_strict(sex_map, default=None),
      pl.col("race").replace_strict(race_map, default=None),
      pl.col("age").map_elements(age_map, return_dtype=pl.String),
      pl.col("highest_educational_level").replace_strict(highest_educational_level_map, default=None),
      pl.col("low_income_status").replace_strict(low_income_status_map, default=None),
      pl.col("employment_status").replace_strict(employment_status_map, default=None),
      pl.col("received_training").replace_strict(received_training_map, default=None),
    ])
)

# %%
# Add an individaual's pre-program occupation title based on the occupation code.
data_lazy = (
    data_lazy.join(
        occupations,
        left_on="occupational_code_pre",
        right_on="occupation_code",
        how="left"
    )
    .drop(["soc_level", "occupation_code_prefix"])
    .rename({"occupation_title": "occupation_title_pre"})
)

# Use an individual's pre-program occupation code to get rti.
data_lazy = (
    data_lazy.join(
        rti_by_occupation,     
        left_on="occupational_code_pre",
        right_on="occupation_code",
        how="left"
    )
    .drop(["occ2000"])
    .rename({
      'r_cog': 'r_cog_pre',
      'r_man': 'r_man_pre',
      'offshor': 'offshor_pre'
    })
    .drop([
        "socwt",
        "nr_cog_anal",
        "nr_cog_pers",
        "nr_man_phys",	
        "nr_man_pers"
    ])
)

# Add an individaual's post-program occupation title based on the occupation code.
data_lazy = (
  data_lazy.join(
      occupations, 
      left_on="occupational_code_post", 
      right_on="occupation_code",
      how="left"
  )
  .drop(["soc_level", "occupation_code_prefix"])
  .rename({"occupation_title": "occupation_title_post"})
)

# Use an individual's pre-program occupation code to get rti.
data_lazy = (
    data_lazy.join(
        rti_by_occupation,
        left_on="occupational_code_post",
        right_on="occupation_code",
        how="left"
    )
    .drop(["occ2000"])
    .rename({
      'r_cog': 'r_cog_post',
      'r_man': 'r_man_post',
      'offshor': 'offshor_post'
    })
    .drop([
        "socwt",
        "nr_cog_anal",
        "nr_cog_pers",
        "nr_man_phys",	
        "nr_man_pers"
    ])
)

# %%
# Join with industry-level rti for pre-program industry codes
data_lazy = (
   data_lazy.join(
      rti_by_subsector,
      left_on="subsector_code_pre",
      right_on="subsector_code",
      how="left"
   )
   .rename({
      "industry_title": "industry_title_pre",
      "subsector_title": "subsector_title_pre",
      "r_cog_industry": "r_cog_industry_pre",
      "r_man_industry": "r_man_industry_pre",
      "offshor_industry": "offshor_industry_pre"
  })
)

# Join with industry-level rti for pre-program industry codes
data_lazy = (
   data_lazy.join(
      rti_by_subsector,
      left_on="subsector_code_post",
      right_on="subsector_code",
      how="left"
   )
   .rename({
      "industry_title": "industry_title_post",
      "subsector_title": "subsector_title_post",
      "r_cog_industry": "r_cog_industry_post",
      "r_man_industry": "r_man_industry_post",
      "offshor_industry": "offshor_industry_post"
  })
)

# %%
# Calculate pre- and post-program difference in wages
data_lazy = data_lazy.with_columns([
    pl.mean_horizontal("wages_1q_pre", "wages_2q_pre", "wages_3q_pre").alias("wages_mean_pre"),
    pl.mean_horizontal("wages_1q_post", "wages_2q_post", "wages_3q_post", "wages_4q_post").alias("wages_mean_post")
])

data_lazy = data_lazy.with_columns([
    (pl.col("wages_mean_post") - pl.col("wages_mean_pre")).alias("diff_wages_mean"),
])

# %%
# Calculate pre- and post-program difference in rti
# A positive difference in pre- and post-program correspond to 
# an occupation change that is has more routine cognitive/manual task 
# or has more offshorable
data_lazy = data_lazy.with_columns([
   (pl.col("r_cog_post") - pl.col("r_cog_pre")).alias("diff_r_cog"),
   (pl.col("r_man_post") - pl.col("r_man_pre")).alias("diff_r_man"),
   (pl.col("offshor_post") - pl.col("offshor_pre")).alias("diff_offshor"),
   (pl.col("r_cog_industry_post") - pl.col("r_cog_industry_pre")).alias("diff_r_cog_industry"),
   (pl.col("r_man_industry_post") - pl.col("r_man_industry_pre")).alias("diff_r_man_industry"),
   (pl.col("offshor_industry_post") - pl.col("offshor_industry_pre")).alias("diff_offshor_industry"),
])

# %%
# Create indicator variables for pre- and post-program differences in 
# routine cognitive, routine manual, offshorability, and wages
data_lazy = data_lazy.with_columns([
    # True if routine cognitive tasks (strictly) increase
    (pl.col("diff_r_cog") > 0).alias("is_r_cog_increased"), 
    # True if routine manual tasks (strictly) increase
    (pl.col("diff_r_man") > 0).alias("is_r_man_increased"), 
    # True if offshorability (strictly) increase
    (pl.col("diff_offshor") > 0).alias("is_offshor_increased"), 
    # True if routine cognitive tasks (strictly) increase
    (pl.col("diff_r_cog_industry") > 0).alias("is_r_cog_industry_increased"), 
    # True if routine manual tasks (strictly) increase
    (pl.col("diff_r_man_industry") > 0).alias("is_r_man_industry_increased"), 
    # True if offshorability (strictly) increase
    (pl.col("diff_offshor_industry") > 0).alias("is_offshor_industry_increased"), 
    # True if wages (strictly) increase
    (pl.col("diff_wages_mean") > 0).alias("is_wages_mean_increased"), 
])

# %%
data_lazy = data_lazy.with_columns(
   (
    # Tier 1: Has wages + all individual-level variables (most complete data)
    pl.col("is_wages_mean_increased").is_not_null() &
    pl.col("is_r_cog_increased").is_not_null() &
    pl.col("is_r_man_increased").is_not_null() &
    pl.col("is_offshor_increased").is_not_null()
   ).alias("has_occupational_outcomes"),
   (
    # Tier 2: Has wages + all industry-level variables (fallback data)
    pl.col("is_wages_mean_increased").is_not_null() &
    pl.col("is_r_cog_industry_increased").is_not_null() &
    pl.col("is_r_man_industry_increased").is_not_null() &
    pl.col("is_offshor_industry_increased").is_not_null()
   ).alias("has_industry_outcomes"),
   (
    # Tier 3: Has wages only (minimal usable data)
    pl.col("is_wages_mean_increased").is_not_null()
   ).alias("has_wages_outcomes")
)

# %%
dimensions = [
    'low_income_status', 'employment_status',
    'race', 'sex', 'age', 'state', 'highest_educational_level',
    'subsector_title_pre', 'subsector_title_post', 'funding_stream'
]

metrics = [
    "percent_r_cog_industry_increased",
    "percent_r_man_industry_increased",
    "percent_offshor_industry_increased",
    "percent_wages_mean_increased",

    "diff_r_cog_industry_median",
    "diff_r_cog_industry_25th",
    "diff_r_cog_industry_75th",
    "diff_r_cog_industry_mean",

    "diff_r_man_industry_median",
    "diff_r_man_industry_25th",
    "diff_r_man_industry_75th",
    "diff_r_man_industry_mean",

    "diff_offshor_industry_median",
    "diff_offshor_industry_25th",
    "diff_offshor_industry_75th",
    "diff_offshor_industry_mean",

    "diff_wages_mean_median",
    "diff_wages_mean_25th",
    "diff_wages_mean_75th",
    "diff_wages_mean_mean",

    "count",
]

column_order = dimensions + metrics

# Clean data - drop rows with nulls in any dimension column
data_lazy = data_lazy.drop_nulls(subset=dimensions)

# %%
# Create all combinations of dimensions from 1 to N
grouping_sets = [list(c) for i in range(1, len(dimensions)+1) for c in combinations(dimensions, i)]

# Filter to "industry" tier data only
data_lazy = data_lazy.filter(pl.col("has_industry_outcomes"))

# %%
data = data_lazy.collect(engine="streaming")

# %%
def consolidate_multiple_columns(data, columns, min_percentage=0.05):
    """Consolidate multiple columns at once, overwriting originals"""
    
    consolidated_data = data
    consolidated_columns = []
    non_consolidated_columns = []
    
    for column in columns:
        # Skip if column is not string/categorical
        if consolidated_data[column].dtype not in [pl.String, pl.Categorical]:
            non_consolidated_columns.append(column)
            print(f"{column}: skipped (not categorical)")
            continue
            
        total_count = consolidated_data.height
        value_counts = consolidated_data.select(pl.col(column).value_counts()).unnest(column)
        
        # Calculate percentages
        value_counts = value_counts.with_columns(
            (pl.col("count") / total_count).alias("percentage")
        )
        
        # Keep categories above threshold
        keep_categories = value_counts.filter(
            pl.col("percentage") >= min_percentage
        ).select(column).to_series().to_list()
        
        original_categories = value_counts.height
        kept_categories = len(keep_categories)
        
        # Only consolidate if we're actually reducing categories
        if kept_categories < original_categories:
            # Overwrite original column with consolidated version
            consolidated_data = consolidated_data.with_columns(
                pl.when(pl.col(column).is_in(keep_categories))
                .then(pl.col(column))
                .otherwise(pl.lit("Other"))
                .alias(column)  # Same name as original
            )
            consolidated_columns.append(column)
            print(f"{column}: consolidated to {kept_categories} categories (from {original_categories})")
        else:
            # No consolidation needed
            non_consolidated_columns.append(column)
            print(f"{column}: no consolidation needed ({original_categories} categories)")
    
    return consolidated_data, consolidated_columns, non_consolidated_columns

# %%
consolidated_data, consolidated_cols, non_consolidated_cols = consolidate_multiple_columns(
    data, dimensions, min_percentage=0.02
)
# Out:
# low_income_status: no consolidation needed (2 categories)
# employment_status: consolidated to 2 categories (from 4)
# race: consolidated to 4 categories (from 7)
# sex: consolidated to 2 categories (from 3)
# age: consolidated to 6 categories (from 8)
# state: consolidated to 13 categories (from 53)
# highest_educational_level: consolidated to 8 categories (from 9)
# subsector_title_pre: consolidated to 10 categories (from 89)
# subsector_title_post: consolidated to 10 categories (from 89)
# funding_stream: consolidated to 4 categories (from 5)

# %%
aggregates = []

aggregations = [
    pl.col("is_r_cog_industry_increased").mean().alias("percent_r_cog_industry_increased"),
    pl.col("is_r_man_industry_increased").mean().alias("percent_r_man_industry_increased"),
    pl.col("is_offshor_industry_increased").mean().alias("percent_offshor_industry_increased"),
    pl.col("is_wages_mean_increased").mean().alias("percent_wages_mean_increased"),

    pl.col("diff_r_cog_industry").median().alias("diff_r_cog_industry_median"),
    pl.col("diff_r_cog_industry").quantile(0.25, interpolation="linear").alias("diff_r_cog_industry_25th"),
    pl.col("diff_r_cog_industry").quantile(0.75, interpolation="linear").alias("diff_r_cog_industry_75th"),
    pl.col("diff_r_cog_industry").mean().alias("diff_r_cog_industry_mean"),

    pl.col("diff_r_man_industry").median().alias("diff_r_man_industry_median"),
    pl.col("diff_r_man_industry").quantile(0.25, interpolation="linear").alias("diff_r_man_industry_25th"),
    pl.col("diff_r_man_industry").quantile(0.75, interpolation="linear").alias("diff_r_man_industry_75th"),
    pl.col("diff_r_man_industry").mean().alias("diff_r_man_industry_mean"),

    pl.col("diff_offshor_industry").median().alias("diff_offshor_industry_median"),
    pl.col("diff_offshor_industry").quantile(0.25, interpolation="linear").alias("diff_offshor_industry_25th"),
    pl.col("diff_offshor_industry").quantile(0.75, interpolation="linear").alias("diff_offshor_industry_75th"),
    pl.col("diff_offshor_industry").mean().alias("diff_offshor_industry_mean"),

    pl.col("diff_wages_mean").median().alias("diff_wages_mean_median"),
    pl.col("diff_wages_mean").quantile(0.25, interpolation="linear").alias("diff_wages_mean_25th"),
    pl.col("diff_wages_mean").quantile(0.75, interpolation="linear").alias("diff_wages_mean_75th"),
    pl.col("diff_wages_mean").mean().alias("diff_wages_mean_mean"),

    pl.len().alias("count"),
]

# Process each grouping combination
num_groups = len(grouping_sets)

for i, group in enumerate(grouping_sets):
    print(f"Aggregating group {i + 1} of {num_groups}")

    # Aggregate by current group
    grouped = consolidated_data.group_by(group).agg(aggregations)
    
    # Add "All" for dimensions not in current group
    for dim in dimensions:
        if dim not in group:
            grouped = grouped.with_columns(pl.lit("All").alias(dim))

    # Reorder columns to match final schema
    grouped = grouped.select(column_order)
    aggregates.append(grouped)

# Grand total row - aggregate all data
grand_total = consolidated_data.select(aggregations)

# Add all dimension columns as "All" and groupby marker
for dim in dimensions:
    grand_total = grand_total.with_columns(pl.lit("All").alias(dim))

# Reorder grand total columns to match other aggregates
grand_total = grand_total.select(column_order)
aggregates.append(grand_total)
# Out:
# Aggregating group 1 of 1023
# Aggregating group 2 of 1023
# Aggregating group 3 of 1023
# Aggregating group 4 of 1023
# Aggregating group 5 of 1023
# Aggregating group 6 of 1023
# Aggregating group 7 of 1023
# Aggregating group 8 of 1023
# Aggregating group 9 of 1023
# Aggregating group 10 of 1023
# Aggregating group 11 of 1023
# Aggregating group 12 of 1023
# Aggregating group 13 of 1023
# Aggregating group 14 of 1023
# Aggregating group 15 of 1023
# Aggregating group 16 of 1023
# Aggregating group 17 of 1023
# Aggregating group 18 of 1023
# Aggregating group 19 of 1023
# Aggregating group 20 of 1023
# Aggregating group 21 of 1023
# Aggregating group 22 of 1023
# Aggregating group 23 of 1023
# Aggregating group 24 of 1023
# Aggregating group 25 of 1023
# Aggregating group 26 of 1023
# Aggregating group 27 of 1023
# Aggregating group 28 of 1023
# Aggregating group 29 of 1023
# Aggregating group 30 of 1023
# Aggregating group 31 of 1023
# Aggregating group 32 of 1023
# Aggregating group 33 of 1023
# Aggregating group 34 of 1023
# Aggregating group 35 of 1023
# Aggregating group 36 of 1023
# Aggregating group 37 of 1023
# Aggregating group 38 of 1023
# Aggregating group 39 of 1023
# Aggregating group 40 of 1023
# Aggregating group 41 of 1023
# Aggregating group 42 of 1023
# Aggregating group 43 of 1023
# Aggregating group 44 of 1023
# Aggregating group 45 of 1023
# Aggregating group 46 of 1023
# Aggregating group 47 of 1023
# Aggregating group 48 of 1023
# Aggregating group 49 of 1023
# Aggregating group 50 of 1023
# Aggregating group 51 of 1023
# Aggregating group 52 of 1023
# Aggregating group 53 of 1023
# Aggregating group 54 of 1023
# Aggregating group 55 of 1023
# Aggregating group 56 of 1023
# Aggregating group 57 of 1023
# Aggregating group 58 of 1023
# Aggregating group 59 of 1023
# Aggregating group 60 of 1023
# Aggregating group 61 of 1023
# Aggregating group 62 of 1023
# Aggregating group 63 of 1023
# Aggregating group 64 of 1023
# Aggregating group 65 of 1023
# Aggregating group 66 of 1023
# Aggregating group 67 of 1023
# Aggregating group 68 of 1023
# Aggregating group 69 of 1023
# Aggregating group 70 of 1023
# Aggregating group 71 of 1023
# Aggregating group 72 of 1023
# Aggregating group 73 of 1023
# Aggregating group 74 of 1023
# Aggregating group 75 of 1023
# Aggregating group 76 of 1023
# Aggregating group 77 of 1023
# Aggregating group 78 of 1023
# Aggregating group 79 of 1023
# Aggregating group 80 of 1023
# Aggregating group 81 of 1023
# Aggregating group 82 of 1023
# Aggregating group 83 of 1023
# Aggregating group 84 of 1023
# Aggregating group 85 of 1023
# Aggregating group 86 of 1023
# Aggregating group 87 of 1023
# Aggregating group 88 of 1023
# Aggregating group 89 of 1023
# Aggregating group 90 of 1023
# Aggregating group 91 of 1023
# Aggregating group 92 of 1023
# Aggregating group 93 of 1023
# Aggregating group 94 of 1023
# Aggregating group 95 of 1023
# Aggregating group 96 of 1023
# Aggregating group 97 of 1023
# Aggregating group 98 of 1023
# Aggregating group 99 of 1023
# Aggregating group 100 of 1023
# Aggregating group 101 of 1023
# Aggregating group 102 of 1023
# Aggregating group 103 of 1023
# Aggregating group 104 of 1023
# Aggregating group 105 of 1023
# Aggregating group 106 of 1023
# Aggregating group 107 of 1023
# Aggregating group 108 of 1023
# Aggregating group 109 of 1023
# Aggregating group 110 of 1023
# Aggregating group 111 of 1023
# Aggregating group 112 of 1023
# Aggregating group 113 of 1023
# Aggregating group 114 of 1023
# Aggregating group 115 of 1023
# Aggregating group 116 of 1023
# Aggregating group 117 of 1023
# Aggregating group 118 of 1023
# Aggregating group 119 of 1023
# Aggregating group 120 of 1023
# Aggregating group 121 of 1023
# Aggregating group 122 of 1023
# Aggregating group 123 of 1023
# Aggregating group 124 of 1023
# Aggregating group 125 of 1023
# Aggregating group 126 of 1023
# Aggregating group 127 of 1023
# Aggregating group 128 of 1023
# Aggregating group 129 of 1023
# Aggregating group 130 of 1023
# Aggregating group 131 of 1023
# Aggregating group 132 of 1023
# Aggregating group 133 of 1023
# Aggregating group 134 of 1023
# Aggregating group 135 of 1023
# Aggregating group 136 of 1023
# Aggregating group 137 of 1023
# Aggregating group 138 of 1023
# Aggregating group 139 of 1023
# Aggregating group 140 of 1023
# Aggregating group 141 of 1023
# Aggregating group 142 of 1023
# Aggregating group 143 of 1023
# Aggregating group 144 of 1023
# Aggregating group 145 of 1023
# Aggregating group 146 of 1023
# Aggregating group 147 of 1023
# Aggregating group 148 of 1023
# Aggregating group 149 of 1023
# Aggregating group 150 of 1023
# Aggregating group 151 of 1023
# Aggregating group 152 of 1023
# Aggregating group 153 of 1023
# Aggregating group 154 of 1023
# Aggregating group 155 of 1023
# Aggregating group 156 of 1023
# Aggregating group 157 of 1023
# Aggregating group 158 of 1023
# Aggregating group 159 of 1023
# Aggregating group 160 of 1023
# Aggregating group 161 of 1023
# Aggregating group 162 of 1023
# Aggregating group 163 of 1023
# Aggregating group 164 of 1023
# Aggregating group 165 of 1023
# Aggregating group 166 of 1023
# Aggregating group 167 of 1023
# Aggregating group 168 of 1023
# Aggregating group 169 of 1023
# Aggregating group 170 of 1023
# Aggregating group 171 of 1023
# Aggregating group 172 of 1023
# Aggregating group 173 of 1023
# Aggregating group 174 of 1023
# Aggregating group 175 of 1023
# Aggregating group 176 of 1023
# Aggregating group 177 of 1023
# Aggregating group 178 of 1023
# Aggregating group 179 of 1023
# Aggregating group 180 of 1023
# Aggregating group 181 of 1023
# Aggregating group 182 of 1023
# Aggregating group 183 of 1023
# Aggregating group 184 of 1023
# Aggregating group 185 of 1023
# Aggregating group 186 of 1023
# Aggregating group 187 of 1023
# Aggregating group 188 of 1023
# Aggregating group 189 of 1023
# Aggregating group 190 of 1023
# Aggregating group 191 of 1023
# Aggregating group 192 of 1023
# Aggregating group 193 of 1023
# Aggregating group 194 of 1023
# Aggregating group 195 of 1023
# Aggregating group 196 of 1023
# Aggregating group 197 of 1023
# Aggregating group 198 of 1023
# Aggregating group 199 of 1023
# Aggregating group 200 of 1023
# Aggregating group 201 of 1023
# Aggregating group 202 of 1023
# Aggregating group 203 of 1023
# Aggregating group 204 of 1023
# Aggregating group 205 of 1023
# Aggregating group 206 of 1023
# Aggregating group 207 of 1023
# Aggregating group 208 of 1023
# Aggregating group 209 of 1023
# Aggregating group 210 of 1023
# Aggregating group 211 of 1023
# Aggregating group 212 of 1023
# Aggregating group 213 of 1023
# Aggregating group 214 of 1023
# Aggregating group 215 of 1023
# Aggregating group 216 of 1023
# Aggregating group 217 of 1023
# Aggregating group 218 of 1023
# Aggregating group 219 of 1023
# Aggregating group 220 of 1023
# Aggregating group 221 of 1023
# Aggregating group 222 of 1023
# Aggregating group 223 of 1023
# Aggregating group 224 of 1023
# Aggregating group 225 of 1023
# Aggregating group 226 of 1023
# Aggregating group 227 of 1023
# Aggregating group 228 of 1023
# Aggregating group 229 of 1023
# Aggregating group 230 of 1023
# Aggregating group 231 of 1023
# Aggregating group 232 of 1023
# Aggregating group 233 of 1023
# Aggregating group 234 of 1023
# Aggregating group 235 of 1023
# Aggregating group 236 of 1023
# Aggregating group 237 of 1023
# Aggregating group 238 of 1023
# Aggregating group 239 of 1023
# Aggregating group 240 of 1023
# Aggregating group 241 of 1023
# Aggregating group 242 of 1023
# Aggregating group 243 of 1023
# Aggregating group 244 of 1023
# Aggregating group 245 of 1023
# Aggregating group 246 of 1023
# Aggregating group 247 of 1023
# Aggregating group 248 of 1023
# Aggregating group 249 of 1023
# Aggregating group 250 of 1023
# Aggregating group 251 of 1023
# Aggregating group 252 of 1023
# Aggregating group 253 of 1023
# Aggregating group 254 of 1023
# Aggregating group 255 of 1023
# Aggregating group 256 of 1023
# Aggregating group 257 of 1023
# Aggregating group 258 of 1023
# Aggregating group 259 of 1023
# Aggregating group 260 of 1023
# Aggregating group 261 of 1023
# Aggregating group 262 of 1023
# Aggregating group 263 of 1023
# Aggregating group 264 of 1023
# Aggregating group 265 of 1023
# Aggregating group 266 of 1023
# Aggregating group 267 of 1023
# Aggregating group 268 of 1023
# Aggregating group 269 of 1023
# Aggregating group 270 of 1023
# Aggregating group 271 of 1023
# Aggregating group 272 of 1023
# Aggregating group 273 of 1023
# Aggregating group 274 of 1023
# Aggregating group 275 of 1023
# Aggregating group 276 of 1023
# Aggregating group 277 of 1023
# Aggregating group 278 of 1023
# Aggregating group 279 of 1023
# Aggregating group 280 of 1023
# Aggregating group 281 of 1023
# Aggregating group 282 of 1023
# Aggregating group 283 of 1023
# Aggregating group 284 of 1023
# Aggregating group 285 of 1023
# Aggregating group 286 of 1023
# Aggregating group 287 of 1023
# Aggregating group 288 of 1023
# Aggregating group 289 of 1023
# Aggregating group 290 of 1023
# Aggregating group 291 of 1023
# Aggregating group 292 of 1023
# Aggregating group 293 of 1023
# Aggregating group 294 of 1023
# Aggregating group 295 of 1023
# Aggregating group 296 of 1023
# Aggregating group 297 of 1023
# Aggregating group 298 of 1023
# Aggregating group 299 of 1023
# Aggregating group 300 of 1023
# Aggregating group 301 of 1023
# Aggregating group 302 of 1023
# Aggregating group 303 of 1023
# Aggregating group 304 of 1023
# Aggregating group 305 of 1023
# Aggregating group 306 of 1023
# Aggregating group 307 of 1023
# Aggregating group 308 of 1023
# Aggregating group 309 of 1023
# Aggregating group 310 of 1023
# Aggregating group 311 of 1023
# Aggregating group 312 of 1023
# Aggregating group 313 of 1023
# Aggregating group 314 of 1023
# Aggregating group 315 of 1023
# Aggregating group 316 of 1023
# Aggregating group 317 of 1023
# Aggregating group 318 of 1023
# Aggregating group 319 of 1023
# Aggregating group 320 of 1023
# Aggregating group 321 of 1023
# Aggregating group 322 of 1023
# Aggregating group 323 of 1023
# Aggregating group 324 of 1023
# Aggregating group 325 of 1023
# Aggregating group 326 of 1023
# Aggregating group 327 of 1023
# Aggregating group 328 of 1023
# Aggregating group 329 of 1023
# Aggregating group 330 of 1023
# Aggregating group 331 of 1023
# Aggregating group 332 of 1023
# Aggregating group 333 of 1023
# Aggregating group 334 of 1023
# Aggregating group 335 of 1023
# Aggregating group 336 of 1023
# Aggregating group 337 of 1023
# Aggregating group 338 of 1023
# Aggregating group 339 of 1023
# Aggregating group 340 of 1023
# Aggregating group 341 of 1023
# Aggregating group 342 of 1023
# Aggregating group 343 of 1023
# Aggregating group 344 of 1023
# Aggregating group 345 of 1023
# Aggregating group 346 of 1023
# Aggregating group 347 of 1023
# Aggregating group 348 of 1023
# Aggregating group 349 of 1023
# Aggregating group 350 of 1023
# Aggregating group 351 of 1023
# Aggregating group 352 of 1023
# Aggregating group 353 of 1023
# Aggregating group 354 of 1023
# Aggregating group 355 of 1023
# Aggregating group 356 of 1023
# Aggregating group 357 of 1023
# Aggregating group 358 of 1023
# Aggregating group 359 of 1023
# Aggregating group 360 of 1023
# Aggregating group 361 of 1023
# Aggregating group 362 of 1023
# Aggregating group 363 of 1023
# Aggregating group 364 of 1023
# Aggregating group 365 of 1023
# Aggregating group 366 of 1023
# Aggregating group 367 of 1023
# Aggregating group 368 of 1023
# Aggregating group 369 of 1023
# Aggregating group 370 of 1023
# Aggregating group 371 of 1023
# Aggregating group 372 of 1023
# Aggregating group 373 of 1023
# Aggregating group 374 of 1023
# Aggregating group 375 of 1023
# Aggregating group 376 of 1023
# Aggregating group 377 of 1023
# Aggregating group 378 of 1023
# Aggregating group 379 of 1023
# Aggregating group 380 of 1023
# Aggregating group 381 of 1023
# Aggregating group 382 of 1023
# Aggregating group 383 of 1023
# Aggregating group 384 of 1023
# Aggregating group 385 of 1023
# Aggregating group 386 of 1023
# Aggregating group 387 of 1023
# Aggregating group 388 of 1023
# Aggregating group 389 of 1023
# Aggregating group 390 of 1023
# Aggregating group 391 of 1023
# Aggregating group 392 of 1023
# Aggregating group 393 of 1023
# Aggregating group 394 of 1023
# Aggregating group 395 of 1023
# Aggregating group 396 of 1023
# Aggregating group 397 of 1023
# Aggregating group 398 of 1023
# Aggregating group 399 of 1023
# Aggregating group 400 of 1023
# Aggregating group 401 of 1023
# Aggregating group 402 of 1023
# Aggregating group 403 of 1023
# Aggregating group 404 of 1023
# Aggregating group 405 of 1023
# Aggregating group 406 of 1023
# Aggregating group 407 of 1023
# Aggregating group 408 of 1023
# Aggregating group 409 of 1023
# Aggregating group 410 of 1023
# Aggregating group 411 of 1023
# Aggregating group 412 of 1023
# Aggregating group 413 of 1023
# Aggregating group 414 of 1023
# Aggregating group 415 of 1023
# Aggregating group 416 of 1023
# Aggregating group 417 of 1023
# Aggregating group 418 of 1023
# Aggregating group 419 of 1023
# Aggregating group 420 of 1023
# Aggregating group 421 of 1023
# Aggregating group 422 of 1023
# Aggregating group 423 of 1023
# Aggregating group 424 of 1023
# Aggregating group 425 of 1023
# Aggregating group 426 of 1023
# Aggregating group 427 of 1023
# Aggregating group 428 of 1023
# Aggregating group 429 of 1023
# Aggregating group 430 of 1023
# Aggregating group 431 of 1023
# Aggregating group 432 of 1023
# Aggregating group 433 of 1023
# Aggregating group 434 of 1023
# Aggregating group 435 of 1023
# Aggregating group 436 of 1023
# Aggregating group 437 of 1023
# Aggregating group 438 of 1023
# Aggregating group 439 of 1023
# Aggregating group 440 of 1023
# Aggregating group 441 of 1023
# Aggregating group 442 of 1023
# Aggregating group 443 of 1023
# Aggregating group 444 of 1023
# Aggregating group 445 of 1023
# Aggregating group 446 of 1023
# Aggregating group 447 of 1023
# Aggregating group 448 of 1023
# Aggregating group 449 of 1023
# Aggregating group 450 of 1023
# Aggregating group 451 of 1023
# Aggregating group 452 of 1023
# Aggregating group 453 of 1023
# Aggregating group 454 of 1023
# Aggregating group 455 of 1023
# Aggregating group 456 of 1023
# Aggregating group 457 of 1023
# Aggregating group 458 of 1023
# Aggregating group 459 of 1023
# Aggregating group 460 of 1023
# Aggregating group 461 of 1023
# Aggregating group 462 of 1023
# Aggregating group 463 of 1023
# Aggregating group 464 of 1023
# Aggregating group 465 of 1023
# Aggregating group 466 of 1023
# Aggregating group 467 of 1023
# Aggregating group 468 of 1023
# Aggregating group 469 of 1023
# Aggregating group 470 of 1023
# Aggregating group 471 of 1023
# Aggregating group 472 of 1023
# Aggregating group 473 of 1023
# Aggregating group 474 of 1023
# Aggregating group 475 of 1023
# Aggregating group 476 of 1023
# Aggregating group 477 of 1023
# Aggregating group 478 of 1023
# Aggregating group 479 of 1023
# Aggregating group 480 of 1023
# Aggregating group 481 of 1023
# Aggregating group 482 of 1023
# Aggregating group 483 of 1023
# Aggregating group 484 of 1023
# Aggregating group 485 of 1023
# Aggregating group 486 of 1023
# Aggregating group 487 of 1023
# Aggregating group 488 of 1023
# Aggregating group 489 of 1023
# Aggregating group 490 of 1023
# Aggregating group 491 of 1023
# Aggregating group 492 of 1023
# Aggregating group 493 of 1023
# Aggregating group 494 of 1023
# Aggregating group 495 of 1023
# Aggregating group 496 of 1023
# Aggregating group 497 of 1023
# Aggregating group 498 of 1023
# Aggregating group 499 of 1023
# Aggregating group 500 of 1023
# Aggregating group 501 of 1023
# Aggregating group 502 of 1023
# Aggregating group 503 of 1023
# Aggregating group 504 of 1023
# Aggregating group 505 of 1023
# Aggregating group 506 of 1023
# Aggregating group 507 of 1023
# Aggregating group 508 of 1023
# Aggregating group 509 of 1023
# Aggregating group 510 of 1023
# Aggregating group 511 of 1023
# Aggregating group 512 of 1023
# Aggregating group 513 of 1023
# Aggregating group 514 of 1023
# Aggregating group 515 of 1023
# Aggregating group 516 of 1023
# Aggregating group 517 of 1023
# Aggregating group 518 of 1023
# Aggregating group 519 of 1023
# Aggregating group 520 of 1023
# Aggregating group 521 of 1023
# Aggregating group 522 of 1023
# Aggregating group 523 of 1023
# Aggregating group 524 of 1023
# Aggregating group 525 of 1023
# Aggregating group 526 of 1023
# Aggregating group 527 of 1023
# Aggregating group 528 of 1023
# Aggregating group 529 of 1023
# Aggregating group 530 of 1023
# Aggregating group 531 of 1023
# Aggregating group 532 of 1023
# Aggregating group 533 of 1023
# Aggregating group 534 of 1023
# Aggregating group 535 of 1023
# Aggregating group 536 of 1023
# Aggregating group 537 of 1023
# Aggregating group 538 of 1023
# Aggregating group 539 of 1023
# Aggregating group 540 of 1023
# Aggregating group 541 of 1023
# Aggregating group 542 of 1023
# Aggregating group 543 of 1023
# Aggregating group 544 of 1023
# Aggregating group 545 of 1023
# Aggregating group 546 of 1023
# Aggregating group 547 of 1023
# Aggregating group 548 of 1023
# Aggregating group 549 of 1023
# Aggregating group 550 of 1023
# Aggregating group 551 of 1023
# Aggregating group 552 of 1023
# Aggregating group 553 of 1023
# Aggregating group 554 of 1023
# Aggregating group 555 of 1023
# Aggregating group 556 of 1023
# Aggregating group 557 of 1023
# Aggregating group 558 of 1023
# Aggregating group 559 of 1023
# Aggregating group 560 of 1023
# Aggregating group 561 of 1023
# Aggregating group 562 of 1023
# Aggregating group 563 of 1023
# Aggregating group 564 of 1023
# Aggregating group 565 of 1023
# Aggregating group 566 of 1023
# Aggregating group 567 of 1023
# Aggregating group 568 of 1023
# Aggregating group 569 of 1023
# Aggregating group 570 of 1023
# Aggregating group 571 of 1023
# Aggregating group 572 of 1023
# Aggregating group 573 of 1023
# Aggregating group 574 of 1023
# Aggregating group 575 of 1023
# Aggregating group 576 of 1023
# Aggregating group 577 of 1023
# Aggregating group 578 of 1023
# Aggregating group 579 of 1023
# Aggregating group 580 of 1023
# Aggregating group 581 of 1023
# Aggregating group 582 of 1023
# Aggregating group 583 of 1023
# Aggregating group 584 of 1023
# Aggregating group 585 of 1023
# Aggregating group 586 of 1023
# Aggregating group 587 of 1023
# Aggregating group 588 of 1023
# Aggregating group 589 of 1023
# Aggregating group 590 of 1023
# Aggregating group 591 of 1023
# Aggregating group 592 of 1023
# Aggregating group 593 of 1023
# Aggregating group 594 of 1023
# Aggregating group 595 of 1023
# Aggregating group 596 of 1023
# Aggregating group 597 of 1023
# Aggregating group 598 of 1023
# Aggregating group 599 of 1023
# Aggregating group 600 of 1023
# Aggregating group 601 of 1023
# Aggregating group 602 of 1023
# Aggregating group 603 of 1023
# Aggregating group 604 of 1023
# Aggregating group 605 of 1023
# Aggregating group 606 of 1023
# Aggregating group 607 of 1023
# Aggregating group 608 of 1023
# Aggregating group 609 of 1023
# Aggregating group 610 of 1023
# Aggregating group 611 of 1023
# Aggregating group 612 of 1023
# Aggregating group 613 of 1023
# Aggregating group 614 of 1023
# Aggregating group 615 of 1023
# Aggregating group 616 of 1023
# Aggregating group 617 of 1023
# Aggregating group 618 of 1023
# Aggregating group 619 of 1023
# Aggregating group 620 of 1023
# Aggregating group 621 of 1023
# Aggregating group 622 of 1023
# Aggregating group 623 of 1023
# Aggregating group 624 of 1023
# Aggregating group 625 of 1023
# Aggregating group 626 of 1023
# Aggregating group 627 of 1023
# Aggregating group 628 of 1023
# Aggregating group 629 of 1023
# Aggregating group 630 of 1023
# Aggregating group 631 of 1023
# Aggregating group 632 of 1023
# Aggregating group 633 of 1023
# Aggregating group 634 of 1023
# Aggregating group 635 of 1023
# Aggregating group 636 of 1023
# Aggregating group 637 of 1023
# Aggregating group 638 of 1023
# Aggregating group 639 of 1023
# Aggregating group 640 of 1023
# Aggregating group 641 of 1023
# Aggregating group 642 of 1023
# Aggregating group 643 of 1023
# Aggregating group 644 of 1023
# Aggregating group 645 of 1023
# Aggregating group 646 of 1023
# Aggregating group 647 of 1023
# Aggregating group 648 of 1023
# Aggregating group 649 of 1023
# Aggregating group 650 of 1023
# Aggregating group 651 of 1023
# Aggregating group 652 of 1023
# Aggregating group 653 of 1023
# Aggregating group 654 of 1023
# Aggregating group 655 of 1023
# Aggregating group 656 of 1023
# Aggregating group 657 of 1023
# Aggregating group 658 of 1023
# Aggregating group 659 of 1023
# Aggregating group 660 of 1023
# Aggregating group 661 of 1023
# Aggregating group 662 of 1023
# Aggregating group 663 of 1023
# Aggregating group 664 of 1023
# Aggregating group 665 of 1023
# Aggregating group 666 of 1023
# Aggregating group 667 of 1023
# Aggregating group 668 of 1023
# Aggregating group 669 of 1023
# Aggregating group 670 of 1023
# Aggregating group 671 of 1023
# Aggregating group 672 of 1023
# Aggregating group 673 of 1023
# Aggregating group 674 of 1023
# Aggregating group 675 of 1023
# Aggregating group 676 of 1023
# Aggregating group 677 of 1023
# Aggregating group 678 of 1023
# Aggregating group 679 of 1023
# Aggregating group 680 of 1023
# Aggregating group 681 of 1023
# Aggregating group 682 of 1023
# Aggregating group 683 of 1023
# Aggregating group 684 of 1023
# Aggregating group 685 of 1023
# Aggregating group 686 of 1023
# Aggregating group 687 of 1023
# Aggregating group 688 of 1023
# Aggregating group 689 of 1023
# Aggregating group 690 of 1023
# Aggregating group 691 of 1023
# Aggregating group 692 of 1023
# Aggregating group 693 of 1023
# Aggregating group 694 of 1023
# Aggregating group 695 of 1023
# Aggregating group 696 of 1023
# Aggregating group 697 of 1023
# Aggregating group 698 of 1023
# Aggregating group 699 of 1023
# Aggregating group 700 of 1023
# Aggregating group 701 of 1023
# Aggregating group 702 of 1023
# Aggregating group 703 of 1023
# Aggregating group 704 of 1023
# Aggregating group 705 of 1023
# Aggregating group 706 of 1023
# Aggregating group 707 of 1023
# Aggregating group 708 of 1023
# Aggregating group 709 of 1023
# Aggregating group 710 of 1023
# Aggregating group 711 of 1023
# Aggregating group 712 of 1023
# Aggregating group 713 of 1023
# Aggregating group 714 of 1023
# Aggregating group 715 of 1023
# Aggregating group 716 of 1023
# Aggregating group 717 of 1023
# Aggregating group 718 of 1023
# Aggregating group 719 of 1023
# Aggregating group 720 of 1023
# Aggregating group 721 of 1023
# Aggregating group 722 of 1023
# Aggregating group 723 of 1023
# Aggregating group 724 of 1023
# Aggregating group 725 of 1023
# Aggregating group 726 of 1023
# Aggregating group 727 of 1023
# Aggregating group 728 of 1023
# Aggregating group 729 of 1023
# Aggregating group 730 of 1023
# Aggregating group 731 of 1023
# Aggregating group 732 of 1023
# Aggregating group 733 of 1023
# Aggregating group 734 of 1023
# Aggregating group 735 of 1023
# Aggregating group 736 of 1023
# Aggregating group 737 of 1023
# Aggregating group 738 of 1023
# Aggregating group 739 of 1023
# Aggregating group 740 of 1023
# Aggregating group 741 of 1023
# Aggregating group 742 of 1023
# Aggregating group 743 of 1023
# Aggregating group 744 of 1023
# Aggregating group 745 of 1023
# Aggregating group 746 of 1023
# Aggregating group 747 of 1023
# Aggregating group 748 of 1023
# Aggregating group 749 of 1023
# Aggregating group 750 of 1023
# Aggregating group 751 of 1023
# Aggregating group 752 of 1023
# Aggregating group 753 of 1023
# Aggregating group 754 of 1023
# Aggregating group 755 of 1023
# Aggregating group 756 of 1023
# Aggregating group 757 of 1023
# Aggregating group 758 of 1023
# Aggregating group 759 of 1023
# Aggregating group 760 of 1023
# Aggregating group 761 of 1023
# Aggregating group 762 of 1023
# Aggregating group 763 of 1023
# Aggregating group 764 of 1023
# Aggregating group 765 of 1023
# Aggregating group 766 of 1023
# Aggregating group 767 of 1023
# Aggregating group 768 of 1023
# Aggregating group 769 of 1023
# Aggregating group 770 of 1023
# Aggregating group 771 of 1023
# Aggregating group 772 of 1023
# Aggregating group 773 of 1023
# Aggregating group 774 of 1023
# Aggregating group 775 of 1023
# Aggregating group 776 of 1023
# Aggregating group 777 of 1023
# Aggregating group 778 of 1023
# Aggregating group 779 of 1023
# Aggregating group 780 of 1023
# Aggregating group 781 of 1023
# Aggregating group 782 of 1023
# Aggregating group 783 of 1023
# Aggregating group 784 of 1023
# Aggregating group 785 of 1023
# Aggregating group 786 of 1023
# Aggregating group 787 of 1023
# Aggregating group 788 of 1023
# Aggregating group 789 of 1023
# Aggregating group 790 of 1023
# Aggregating group 791 of 1023
# Aggregating group 792 of 1023
# Aggregating group 793 of 1023
# Aggregating group 794 of 1023
# Aggregating group 795 of 1023
# Aggregating group 796 of 1023
# Aggregating group 797 of 1023
# Aggregating group 798 of 1023
# Aggregating group 799 of 1023
# Aggregating group 800 of 1023
# Aggregating group 801 of 1023
# Aggregating group 802 of 1023
# Aggregating group 803 of 1023
# Aggregating group 804 of 1023
# Aggregating group 805 of 1023
# Aggregating group 806 of 1023
# Aggregating group 807 of 1023
# Aggregating group 808 of 1023
# Aggregating group 809 of 1023
# Aggregating group 810 of 1023
# Aggregating group 811 of 1023
# Aggregating group 812 of 1023
# Aggregating group 813 of 1023
# Aggregating group 814 of 1023
# Aggregating group 815 of 1023
# Aggregating group 816 of 1023
# Aggregating group 817 of 1023
# Aggregating group 818 of 1023
# Aggregating group 819 of 1023
# Aggregating group 820 of 1023
# Aggregating group 821 of 1023
# Aggregating group 822 of 1023
# Aggregating group 823 of 1023
# Aggregating group 824 of 1023
# Aggregating group 825 of 1023
# Aggregating group 826 of 1023
# Aggregating group 827 of 1023
# Aggregating group 828 of 1023
# Aggregating group 829 of 1023
# Aggregating group 830 of 1023
# Aggregating group 831 of 1023
# Aggregating group 832 of 1023
# Aggregating group 833 of 1023
# Aggregating group 834 of 1023
# Aggregating group 835 of 1023
# Aggregating group 836 of 1023
# Aggregating group 837 of 1023
# Aggregating group 838 of 1023
# Aggregating group 839 of 1023
# Aggregating group 840 of 1023
# Aggregating group 841 of 1023
# Aggregating group 842 of 1023
# Aggregating group 843 of 1023
# Aggregating group 844 of 1023
# Aggregating group 845 of 1023
# Aggregating group 846 of 1023
# Aggregating group 847 of 1023
# Aggregating group 848 of 1023
# Aggregating group 849 of 1023
# Aggregating group 850 of 1023
# Aggregating group 851 of 1023
# Aggregating group 852 of 1023
# Aggregating group 853 of 1023
# Aggregating group 854 of 1023
# Aggregating group 855 of 1023
# Aggregating group 856 of 1023
# Aggregating group 857 of 1023
# Aggregating group 858 of 1023
# Aggregating group 859 of 1023
# Aggregating group 860 of 1023
# Aggregating group 861 of 1023
# Aggregating group 862 of 1023
# Aggregating group 863 of 1023
# Aggregating group 864 of 1023
# Aggregating group 865 of 1023
# Aggregating group 866 of 1023
# Aggregating group 867 of 1023
# Aggregating group 868 of 1023
# Aggregating group 869 of 1023
# Aggregating group 870 of 1023
# Aggregating group 871 of 1023
# Aggregating group 872 of 1023
# Aggregating group 873 of 1023
# Aggregating group 874 of 1023
# Aggregating group 875 of 1023
# Aggregating group 876 of 1023
# Aggregating group 877 of 1023
# Aggregating group 878 of 1023
# Aggregating group 879 of 1023
# Aggregating group 880 of 1023
# Aggregating group 881 of 1023
# Aggregating group 882 of 1023
# Aggregating group 883 of 1023
# Aggregating group 884 of 1023
# Aggregating group 885 of 1023
# Aggregating group 886 of 1023
# Aggregating group 887 of 1023
# Aggregating group 888 of 1023
# Aggregating group 889 of 1023
# Aggregating group 890 of 1023
# Aggregating group 891 of 1023
# Aggregating group 892 of 1023
# Aggregating group 893 of 1023
# Aggregating group 894 of 1023
# Aggregating group 895 of 1023
# Aggregating group 896 of 1023
# Aggregating group 897 of 1023
# Aggregating group 898 of 1023
# Aggregating group 899 of 1023
# Aggregating group 900 of 1023
# Aggregating group 901 of 1023
# Aggregating group 902 of 1023
# Aggregating group 903 of 1023
# Aggregating group 904 of 1023
# Aggregating group 905 of 1023
# Aggregating group 906 of 1023
# Aggregating group 907 of 1023
# Aggregating group 908 of 1023
# Aggregating group 909 of 1023
# Aggregating group 910 of 1023
# Aggregating group 911 of 1023
# Aggregating group 912 of 1023
# Aggregating group 913 of 1023
# Aggregating group 914 of 1023
# Aggregating group 915 of 1023
# Aggregating group 916 of 1023
# Aggregating group 917 of 1023
# Aggregating group 918 of 1023
# Aggregating group 919 of 1023
# Aggregating group 920 of 1023
# Aggregating group 921 of 1023
# Aggregating group 922 of 1023
# Aggregating group 923 of 1023
# Aggregating group 924 of 1023
# Aggregating group 925 of 1023
# Aggregating group 926 of 1023
# Aggregating group 927 of 1023
# Aggregating group 928 of 1023
# Aggregating group 929 of 1023
# Aggregating group 930 of 1023
# Aggregating group 931 of 1023
# Aggregating group 932 of 1023
# Aggregating group 933 of 1023
# Aggregating group 934 of 1023
# Aggregating group 935 of 1023
# Aggregating group 936 of 1023
# Aggregating group 937 of 1023
# Aggregating group 938 of 1023
# Aggregating group 939 of 1023
# Aggregating group 940 of 1023
# Aggregating group 941 of 1023
# Aggregating group 942 of 1023
# Aggregating group 943 of 1023
# Aggregating group 944 of 1023
# Aggregating group 945 of 1023
# Aggregating group 946 of 1023
# Aggregating group 947 of 1023
# Aggregating group 948 of 1023
# Aggregating group 949 of 1023
# Aggregating group 950 of 1023
# Aggregating group 951 of 1023
# Aggregating group 952 of 1023
# Aggregating group 953 of 1023
# Aggregating group 954 of 1023
# Aggregating group 955 of 1023
# Aggregating group 956 of 1023
# Aggregating group 957 of 1023
# Aggregating group 958 of 1023
# Aggregating group 959 of 1023
# Aggregating group 960 of 1023
# Aggregating group 961 of 1023
# Aggregating group 962 of 1023
# Aggregating group 963 of 1023
# Aggregating group 964 of 1023
# Aggregating group 965 of 1023
# Aggregating group 966 of 1023
# Aggregating group 967 of 1023
# Aggregating group 968 of 1023
# Aggregating group 969 of 1023
# Aggregating group 970 of 1023
# Aggregating group 971 of 1023
# Aggregating group 972 of 1023
# Aggregating group 973 of 1023
# Aggregating group 974 of 1023
# Aggregating group 975 of 1023
# Aggregating group 976 of 1023
# Aggregating group 977 of 1023
# Aggregating group 978 of 1023
# Aggregating group 979 of 1023
# Aggregating group 980 of 1023
# Aggregating group 981 of 1023
# Aggregating group 982 of 1023
# Aggregating group 983 of 1023
# Aggregating group 984 of 1023
# Aggregating group 985 of 1023
# Aggregating group 986 of 1023
# Aggregating group 987 of 1023
# Aggregating group 988 of 1023
# Aggregating group 989 of 1023
# Aggregating group 990 of 1023
# Aggregating group 991 of 1023
# Aggregating group 992 of 1023
# Aggregating group 993 of 1023
# Aggregating group 994 of 1023
# Aggregating group 995 of 1023
# Aggregating group 996 of 1023
# Aggregating group 997 of 1023
# Aggregating group 998 of 1023
# Aggregating group 999 of 1023
# Aggregating group 1000 of 1023
# Aggregating group 1001 of 1023
# Aggregating group 1002 of 1023
# Aggregating group 1003 of 1023
# Aggregating group 1004 of 1023
# Aggregating group 1005 of 1023
# Aggregating group 1006 of 1023
# Aggregating group 1007 of 1023
# Aggregating group 1008 of 1023
# Aggregating group 1009 of 1023
# Aggregating group 1010 of 1023
# Aggregating group 1011 of 1023
# Aggregating group 1012 of 1023
# Aggregating group 1013 of 1023
# Aggregating group 1014 of 1023
# Aggregating group 1015 of 1023
# Aggregating group 1016 of 1023
# Aggregating group 1017 of 1023
# Aggregating group 1018 of 1023
# Aggregating group 1019 of 1023
# Aggregating group 1020 of 1023
# Aggregating group 1021 of 1023
# Aggregating group 1022 of 1023
# Aggregating group 1023 of 1023

# %%
# Combine all aggregations into single dataframe
index_df = pl.concat(aggregates)

index_df = index_df.with_columns([
    pl.col(c).cast(pl.Categorical) for c in dimensions
])

# %%
index_df.write_parquet("../data/processed/index.parquet", compression="zstd")
